# %% [markdown]
# ### Mediapipe Documentation: https://ai.google.dev/edge/mediapipe/solutions/guide ###

# %% [markdown]
# ## 0. Setup and Imports ##

# %%
# %pip install mediapipe opencv-python

# %%
from workouts import *

# %%
track_shoulder_presses(video_source=0)  # Change video_source if neccessary
# Out:
# C:\Users\dougl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
# Run the tracker on a prerecorded video
track_shoulder_presses_on_video("dumbbelloverheadshoulderpress_S3_FL.mp4", "dumbbell_overhead_shoulder_press_output.mp4", "shoulder_press.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the CSV file
df = pd.read_csv("shoulder_press.csv")

# Show the first few rows of the data
df.head()
# Out:
#    Frame  Time  Left_Shoulder_X  Left_Shoulder_Y  Left_Elbow_X  Left_Elbow_Y  \
# 0      0  0.00       535.009986       276.132023    551.255375    340.254173
# 1      1  0.02       535.010844       275.851491    551.259989    340.220028
# 2      2  0.04       535.010523       275.694501    551.271898    340.218151
# 3      3  0.06       535.008377       275.547060    551.282948    340.198517
# 4      4  0.08       535.006338       275.381917    551.290512    340.173921
#
#    Left_Wrist_X  Left_Wrist_Y  Right_Shoulder_X  Right_Shoulder_Y  \
# 0    559.598708    401.610455        454.001749        275.208163
# 1    559.573925    401.750520        454.004699        275.309256
# 2    559.552199    401.921618        454.007703        275.437519
# 3    559.529346    402.006295        454.017305        275.510582
# 4    559.514916    402.067798        454.022992        275.547892
#
#    Right_Elbow_X  Right_Elbow_Y  Right_Wrist_X  Right_Wrist_Y  Left_Angle  \
# 0     445.644817     338.751599     427.661678     393.828911  173.526896
# 1     445.718363     338.657615     427.773473     393.711108  173.527167
# 2     445.816505     338.611400     427.908924     393.518659  173.517419
# 3     445.951849     338.542843     428.007254     393.380338  173.505601
# 4     446.047121     338.483807     428.086728     393.256313  173.496707
#
#    Right_Angle  Left_Wrist_Y.1  Right_Wrist_Y.1 Left_State Right_State
# 0   169.410038      401.610455       393.828911    RESTING     RESTING
# 1   169.404390      401.750520       393.711108    RESTING     RESTING
# 2   169.377753      401.921618       393.518659    RESTING     RESTING
# 3   169.326325      402.006295       393.380338    RESTING     RESTING
# 4   169.274623      402.067798       393.256313    RESTING     RESTING

# %%
# Get summary statistics of the data
df.describe()

# Get information about the data types and missing values
df.info()

# %%
# Plot the angles for the left and right arms over time
plt.figure(figsize=(10, 6))
plt.plot(df['Time'], df['Left_Angle'], label='Left Arm Angle')
plt.plot(df['Time'], df['Right_Angle'], label='Right Arm Angle')
plt.xlabel('Time (seconds)')
plt.ylabel('Angle (degrees)')
plt.title('Arm Angles Over Time')
plt.legend()
plt.show()

# %%
# Aggregate data by time intervals (e.g., 1-second bins)
df['Time_Binned'] = (df['Time'] // 1).astype(int)
time_grouped = df.groupby('Time_Binned').mean()

# Plot average angles over time
plt.figure(figsize=(10, 6))
plt.plot(time_grouped.index, time_grouped['Left_Angle'], label='Average Left Arm Angle')
plt.plot(time_grouped.index, time_grouped['Right_Angle'], label='Average Right Arm Angle')
plt.xlabel('Time (seconds)')
plt.ylabel('Average Angle (degrees)')
plt.title('Average Arm Angles Over Time')
plt.legend()
plt.show()
